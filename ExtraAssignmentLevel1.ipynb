# %%
print("HOPE AI ")
# Out:
# HOPE AI

# %%
insName=input("Enter your institute name? :")
# Out:
# Enter your institute name? : Hope AI

# %%
Name=input("Enter your name:")
Age=input("Enter your age:")
SchoolName=input("Enter your school name:")
Degree=input("Enter your drgree:")
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru School
# Enter your drgree: B.E CSE

# %%
a=43
b=34
add=a+b
print("a=",a)
print("b=",b)
print("add=",add)
# Out:
# a= 43
# b= 34
# add= 77

# %%
a=43
b=34
sub=a-b
print("a=",a)
print("b=",b)
print("sub=",sub)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
a=63
b=97
Mul=a*b
print("a=",a)
print("b=",b)
print("Mul=",Mul)
# Out:
# a= 63
# b= 97
# Mul= 6111

# %%
a=76
b=31
floa=a/b
print("a=",a)
print("b=",b)
print("Float Div=",floa)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
a=76
b=31
floo=a//b
print("a=",a)
print("b=",b)
print("Floor Div=",floo)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
a=76
b=31
Mod=a%b
print("a=",a)
print("b=",b)
print("Modulo=",Mod)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
a=4
b=4
pow=a**b
print("a=",a)
print("b=",b)
print("Power=",pow)
# Out:
# a= 4
# b= 4
# Power= 256
